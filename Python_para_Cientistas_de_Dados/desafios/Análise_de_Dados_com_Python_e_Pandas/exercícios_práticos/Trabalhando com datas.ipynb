# %% [markdown]
# # **Trabalhando com datas**

# %%
# Importando a biblioteca Pandas
import pandas as pd

# %%
# Criar variável de data frame a partir dos arquivos .xlsx
dfAracaju = pd.read_excel('Aracaju.xlsx')
dfFortaleza = pd.read_excel('Fortaleza.xlsx')
dfNatal = pd.read_excel('Natal.xlsx')
dfRecife = pd.read_excel('Recife.xlsx')
dfSalvador = pd.read_excel('Salvador.xlsx')

# %%
# Conferir as estrutura do dataframe de Aracaju
dfAracaju.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde
# 0  Aracaju 2018-01-01  142.00    1520     1
# 1  Aracaju 2018-01-01   14.21    1522     6
# 2  Aracaju 2018-01-01   71.55    1520     1
# 3  Aracaju 2018-01-01    3.01    1521     7
# 4  Aracaju 2018-01-01   24.51    1522     8

# %%
# Juntar (concatenar) todos os data frames em um só
df = pd.concat([dfAracaju, dfFortaleza, dfNatal, dfRecife, dfSalvador])

# %%
# Exbibir as primeiras linhas do dataframe concatenado
df.head()
# Out:
#     Cidade                 Data  Vendas  LojaID  Qtde
# 0  Aracaju  1514764800000000000  142.00    1520     1
# 1  Aracaju  1514764800000000000   14.21    1522     6
# 2  Aracaju  1514764800000000000   71.55    1520     1
# 3  Aracaju  1514764800000000000    3.01    1521     7
# 4  Aracaju  1514764800000000000   24.51    1522     8

# %%
df['Receita'] = df['Vendas'].mul(df['Qtde'])

# %%
# Verificar o tipo de dado de cada coluna
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
# Transformar coluna 'Data' em tipo 'int64'
df['Data'] = df['Data'].astype('int64')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: casting datetime64[ns] values to int64 with .astype(...) is deprecated and will raise in a future version. Use .view(...) instead.

# %%
# Verificar novamente o tipo de dado de cada coluna
df.dtypes
# Out:
# Cidade     object
# Data        int64
# Vendas    float64
# LojaID      int64
# Qtde        int64
# dtype: object

# %%
# Transformar coluna 'Data' de volta em em tipo 'datetime64'
df['Data'] = pd.to_datetime(df['Data'])

# %%
# Verificar novamente o tipo de dado de cada coluna
df.dtypes
# Out:
# Cidade            object
# Data      datetime64[ns]
# Vendas           float64
# LojaID             int64
# Qtde               int64
# dtype: object

# %%
# Retornar a soma da receita agrupada por ano
df.groupby(df['Data'].dt.year)['Receita'].sum()
# Out:
# Data
# 2018    118176.53
# 2019    228246.45
# Name: Receita, dtype: float64

# %%
# Criar coluna 'Ano da venda'
df['Ano da venda'] = df['Data'].dt.year

# %%
# Verificar alteração no data frame
df.head()
# Out:
#     Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano da venda
# 0  Aracaju 2018-01-01  142.00    1520     1   142.00          2018
# 1  Aracaju 2018-01-01   14.21    1522     6    85.26          2018
# 2  Aracaju 2018-01-01   71.55    1520     1    71.55          2018
# 3  Aracaju 2018-01-01    3.01    1521     7    21.07          2018
# 4  Aracaju 2018-01-01   24.51    1522     8   196.08          2018

# %%
# Criar colunas 'Mês da venda" e "Dia da venda"
df['Mes da venda'], df['Dia da venda'] = (df['Data'].dt.month, df['Data'].dt.day)

# %%
# Verificar alteração no data frame
df.sample(5)
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano da venda  \
# 124    Recife 2019-03-02   47.98     983     7   335.86          2019
# 115   Aracaju 2018-01-01   50.99    1522    10   509.90          2018
# 24     Recife 2019-01-01   13.00     983     2    26.00          2019
# 7    Salvador 2019-02-11    6.13    1034     2    12.26          2019
# 0     Aracaju 2018-01-01  142.00    1520     1   142.00          2018
#
#      Mes da venda  Dia da venda
# 124             3             2
# 115             1             1
# 24              1             1
# 7               2            11
# 0               1             1

# %%
# Retornar data mais antiga
df['Data'].min()
# Out:
# Timestamp('2018-01-01 00:00:00')

# %%
# Calcular diferença de dias entre a data da venda a e a data mais antiga
df['Diferenca de dias'] = df['Data'] - df['Data'].min()

# %%
# Verificar alteração no data frame
df.sample(5)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano da venda  \
# 141   Salvador 2019-03-02    9.08    1036     1     9.08          2019
# 196      Natal 2019-01-02  145.09    1036     2   290.18          2019
# 217   Salvador 2019-01-02   37.65    1036     2    75.30          2019
# 112  Fortaleza 2019-03-02  133.59     982     1   133.59          2019
# 126    Aracaju 2018-01-01   13.41    1520     7    93.87          2018
#
#      Mes da venda  Dia da venda Diferenca de dias
# 141             3             2          425 days
# 196             1             2          366 days
# 217             1             2          366 days
# 112             3             2          425 days
# 126             1             1            0 days

# %%
# Criar coluna "Trimestre da venda"
df['Trimestre da venda'] = df['Data'].dt.quarter

# %%
# Verificar alteração no data frame
df.sample(5)
# Out:
#        Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano da venda  \
# 96     Recife 2019-01-01  165.36     982     7  1157.52          2019
# 30      Natal 2018-10-02  856.00     853     4  3424.00          2018
# 95    Aracaju 2018-01-01  127.43    1522     9  1146.87          2018
# 56    Aracaju 2018-01-01   41.90    1523     6   251.40          2018
# 205  Salvador 2019-01-02  196.09    1037     1   196.09          2019
#
#      Mes da venda  Dia da venda Diferenca de dias  Trimestre da venda
# 96              1             1          365 days                   1
# 30             10             2          274 days                   4
# 95              1             1            0 days                   1
# 56              1             1            0 days                   1
# 205             1             2          366 days                   1

# %%
#Criar variável 'vendas_marco_2019' com todas as vendas do mês de 3 do ano de 2019
vendas_marco_2019 = df.loc[(df['Data'].dt.year == 2019) & (df['Data'].dt.month == 3)]

# %%
# Verificar variável
vendas_marco_2019.sample(20)
# Out:
#         Cidade       Data  Vendas  LojaID  Qtde  Receita  Ano da venda  \
# 66       Natal 2019-03-24  559.00     853     2  1118.00          2019
# 120     Recife 2019-03-02  184.90     982     4   739.60          2019
# 139     Recife 2019-03-02  141.16     980     7   988.12          2019
# 116  Fortaleza 2019-03-02   79.10     982     2   158.20          2019
# 138     Recife 2019-03-02  150.38     983     6   902.28          2019
# 111     Recife 2019-03-02    8.00     981     3    24.00          2019
# 141   Salvador 2019-03-02    9.08    1036     1     9.08          2019
# 113     Recife 2019-03-02   38.63     980     2    77.26          2019
# 126  Fortaleza 2019-03-02   41.87     980     8   334.96          2019
# 140     Recife 2019-03-02  166.89     983     5   834.45          2019
# 135   Salvador 2019-03-02    9.95    1037     3    29.85          2019
# 117   Salvador 2019-03-02   39.41    1034     1    39.41          2019
# 112   Salvador 2019-03-02   43.00    1036     3   129.00          2019
# 110     Recife 2019-03-02   51.98     983     6   311.88          2019
# 69       Natal 2019-03-24  817.00     852     4  3268.00          2019
# 140   Salvador 2019-03-02   20.79    1036     2    41.58          2019
# 138   Salvador 2019-03-02  212.03    1037     3   636.09          2019
# 119     Recife 2019-03-02  152.30     982     7  1066.10          2019
# 111   Salvador 2019-03-02  147.35    1037     2   294.70          2019
# 117     Recife 2019-03-02   15.42     983     8   123.36          2019
#
#      Mes da venda  Dia da venda Diferenca de dias  Trimestre da venda
# 66              3            24          447 days                   1
# 120             3             2          425 days                   1
# 139             3             2          425 days                   1
# 116             3             2          425 days                   1
# 138             3             2          425 days                   1
# 111             3             2          425 days                   1
# 141             3             2          425 days                   1
# 113             3             2          425 days                   1
# 126             3             2          425 days                   1
# 140             3             2          425 days                   1
# 135             3             2          425 days                   1
# 117             3             2          425 days                   1
# 112             3             2          425 days                   1
# 110             3             2          425 days                   1
# 69              3            24          447 days                   1
# 140             3             2          425 days                   1
# 138             3             2          425 days                   1
# 119             3             2          425 days                   1
# 111             3             2          425 days                   1
# 117             3             2          425 days                   1
