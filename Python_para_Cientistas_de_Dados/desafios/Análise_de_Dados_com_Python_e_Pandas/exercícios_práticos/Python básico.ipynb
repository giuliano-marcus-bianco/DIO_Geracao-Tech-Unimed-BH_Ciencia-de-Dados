# %%
print('Olá mundo!')
# Out:
# Olá mundo!

# %%
print('Estou aprendendo Python')
# Out:
# Estou aprendendo Python

# %%
'Estou aprendendo Python'
# Out:
# 'Estou aprendendo Python'

# %%
1 + 1
# Out:
# 2

# %%
10 - 2
# Out:
# 8

# %%
# Esse é um comentário em Python

# %%
# multiplicação
2 * 2
# Out:
# 4

# %%
# divisão
10 / 2
# Out:
# 5.0

# %%
# variáveis tipo int
a = 4
b = 6

# %%
# somando variáveis
a + b
# Out:
# 10

# %%
# variáveis tipo string
frase = 'Python para análise de dados'

# %%
# trabalhando com variáveis tipo string
frase[0]
# Out:
# 'P'

# %%
# operação de fatiamento (anotação inclusiva à esquerda [0], mas não à direita [10])
frase[0:10]
# Out:
# 'Python par'

# %%
frase[10:]
# Out:
# 'a análise de dados'

# %%
frase[:17]
# Out:
# 'Python para análi'

# %%
frase.count('dados')
# Out:
# 1

# %%
frase.lower()
# Out:
# 'python para análise de dados'

# %%
frase.upper()
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS'

# %%
frase.replace('Python', 'Frases')
# Out:
# 'Frases para análise de dados'

# %%
frase = frase.upper()

# %%
frase
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS'
